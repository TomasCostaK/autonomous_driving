# %% [markdown]
# # Visualize depth map
# ## Needed imports for visualization

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Import image, do this in a loop later

# %%
img_array = np.load('../Examples/depth_map.npy')

# %% [markdown]
# ## Show depth map

# %%
plt.imshow(img_array, cmap='gray')
plt.show()
